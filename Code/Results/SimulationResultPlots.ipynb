# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_accuracy(results, labels, y_label, title, multiplier = 0.7, accuracy_flag = True):
    f, a = plt.subplots(1,2, figsize = (12,5))
    for j, temp_results in enumerate(results):
        for i, result in enumerate(temp_results):
            a[j].plot(np.arange(0,result.shape[1]), np.mean(result,0), label=labels[j][i])
            a[j].fill_between(np.arange(0,result.shape[1]),
                             np.mean(result,0)+(multiplier*np.std(result,0)/np.sqrt(result.shape[0])), 
                             np.mean(result,0)-(multiplier*np.std(result,0)/np.sqrt(result.shape[0])), alpha=0.5)
            a[j].set_ylabel(y_label)
            a[j].set_xlabel('Epoch')
            a[j].legend()
            if accuracy_flag:
                a[j].set_ylim([0.0,1.1])
            a[j].grid(True)
        a[j].set_title(title[j])
    plt.show()

# %% [markdown]
# # Large Model results
# ### batch size = 4, training subsample size = 8000, validation subsample size = 2000
# ### From scratch
# #### embeded dim = 64 induced dim = 128 dropout = 0.2 stack = 3 optimizer: Adam = 1e-3 epochs = 250
# #### Gelu activation
#
# ## Pretrainedmodel
# #### batch size = 32, training subsample size = 1024
# #### embeded dim = 64 induced dim = 128 dropout = 0.2 stack = 3 optimizer: Adam = 1e-3 epochs = 200 temperature = 2.0
#
# #### additional layer with LeakyReLU: projection_dim = 256 dropout = 0.1 optimizer: Adam = 1e-3 epochs = 250

# %%
LNMtrain_accuracy = np.loadtxt("./Large Models/NewModel/train_accuracy.txt")
LNMvalidation_accuracy = np.loadtxt("./Large Models/NewModel/validation_accuracy.txt")

LPTtrain_accuracy = np.loadtxt("./Large Models/Pretrained/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/Pretrained/validation_accuracy.txt")

# %%
data = [[LNMtrain_accuracy, LNMvalidation_accuracy], [LPTtrain_accuracy, LPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']
plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
LNMtrain_loss = np.loadtxt("./Large Models/NewModel/train_loss.txt")
LNMvalidation_loss = np.loadtxt("./Large Models/NewModel/validation_loss.txt")

LPTtrain_loss = np.loadtxt("./Large Models/Pretrained/train_loss.txt")
LPTvalidation_loss = np.loadtxt("./Large Models/Pretrained/validation_loss.txt")

# %%
data = [[LNMtrain_loss, LNMvalidation_loss], [LPTtrain_loss, LPTvalidation_loss]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']
plot_accuracy(data, labels, y_label = 'Loss (P)', accuracy_flag = False, title = titles)

# %% [markdown]
# # Small Model results
# ### batch size = 4, training subsample size = 8000, validation subsample size = 2000
# ## From scratch
# ### embeded dim = 32 induced dim = 64 dropout = 0.05 stack = 3 optimizer: Adam = 1e-3 epochs = 250
# ### Gelu activation
#
# ## Pretrainedmodel
# ### batch size = 32, training subsample size = 1024
# ### embeded dim = 32 induced dim = 64 dropout = 0.05 stack = 3 optimizer: Adam = 1e-3 epochs = 200 temperature = 2.0
#
# ### additional layer with LeakyReLU: projection_dim = 256 dropout = 0.1 optimizer: Adam = 1e-3 epochs = 250

# %%
SNMtrain_accuracy = np.loadtxt("./Small Models/NewModel/train_accuracy.txt")
SNMvalidation_accuracy = np.loadtxt("./Small Models/NewModel/validation_accuracy.txt")

SPTtrain_accuracy = np.loadtxt("./Small Models/Pretrained/train_accuracy.txt")
SPTvalidation_accuracy = np.loadtxt("./Small Models/Pretrained/validation_accuracy.txt")

# %%
data = [[SNMtrain_accuracy, SNMvalidation_accuracy], [SPTtrain_accuracy, SPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']
plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
SNMtrain_loss = np.loadtxt("./Small Models/NewModel/train_loss.txt")
SNMvalidation_loss = np.loadtxt("./Small Models/NewModel/validation_loss.txt")

SPTtrain_loss = np.loadtxt("./Small Models/Pretrained/train_loss.txt")
SPTvalidation_loss = np.loadtxt("./Small Models/Pretrained/validation_loss.txt")

# %%
data = [[SNMtrain_loss, SNMvalidation_loss], [SPTtrain_loss, SPTvalidation_loss]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']
plot_accuracy(data, labels, y_label = 'Loss (P)', accuracy_flag = False, title = titles)

# %% [markdown]
# # Each experiment follow the file naming convention:
# ## Standard set transformer: embeddim_numheads_inducedim_stack_dropout
# ## Contrastive pretrained: masked_encoder_embeddim_numheads_inducedim_stack_dropout(_optional projectiondim)(_optional dropout)

# %% [markdown]
# # Small model
# ## From scratch vs Pretrained
# ### Both with same architecture difference
#
# # ****************** STRAT *****************************

# %%
SNMtrain_accuracy = np.loadtxt("./Small Models/NewModel/32_16_64_3_0.05/train_accuracy.txt")
SNMvalidation_accuracy = np.loadtxt("./Small Models/NewModel/32_16_64_3_0.05/validation_accuracy.txt")

SPTtrain_accuracy = np.loadtxt("./Small Models/Pretrained/masked_encoder_32_16_64_3_0.05/train_accuracy.txt")
SPTvalidation_accuracy = np.loadtxt("./Small Models/Pretrained/masked_encoder_32_16_64_3_0.05/validation_accuracy.txt")

# %%
data = [[SNMtrain_accuracy, SNMvalidation_accuracy], [SPTtrain_accuracy, SPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']
plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
SNMtrain_accuracy = np.loadtxt("./Small Models/NewModel/32_16_64_3_0.2/train_accuracy.txt")
SNMvalidation_accuracy = np.loadtxt("./Small Models/NewModel/32_16_64_3_0.2/validation_accuracy.txt")

SPTtrain_accuracy = np.loadtxt("./Small Models/Pretrained/masked_encoder_32_16_64_3_0.2/train_accuracy.txt")
SPTvalidation_accuracy = np.loadtxt("./Small Models/Pretrained/masked_encoder_32_16_64_3_0.2/validation_accuracy.txt")

data = [[SNMtrain_accuracy, SNMvalidation_accuracy], [SPTtrain_accuracy, SPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']
plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
SNMtrain_accuracy = np.loadtxt("./Small Models/NewModel/32_32_64_3_0.05/train_accuracy.txt")
SNMvalidation_accuracy = np.loadtxt("./Small Models/NewModel/32_32_64_3_0.05/validation_accuracy.txt")

SPTtrain_accuracy = np.loadtxt("./Small Models/Pretrained/masked_encoder_32_32_64_3_0.05/train_accuracy.txt")
SPTvalidation_accuracy = np.loadtxt("./Small Models/Pretrained/masked_encoder_32_32_64_3_0.05/validation_accuracy.txt")

data = [[SNMtrain_accuracy, SNMvalidation_accuracy], [SPTtrain_accuracy, SPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']
plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
SNMtrain_accuracy = np.loadtxt("./Small Models/NewModel/32_32_64_3_0.2/train_accuracy.txt")
SNMvalidation_accuracy = np.loadtxt("./Small Models/NewModel/32_32_64_3_0.2/validation_accuracy.txt")

SPTtrain_accuracy = np.loadtxt("./Small Models/Pretrained/masked_encoder_32_32_64_3_0.2/train_accuracy.txt")
SPTvalidation_accuracy = np.loadtxt("./Small Models/Pretrained/masked_encoder_32_32_64_3_0.2/validation_accuracy.txt")

data = [[SNMtrain_accuracy, SNMvalidation_accuracy], [SPTtrain_accuracy, SPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %% [markdown]
# # ****************** Small END *****************************

# %% [markdown]
# # Large model
# ## From scratch vs Pretrained
# ### Both with same architecture difference
#
# # ****************** Large START *********************

# %%
LNMtrain_accuracy = np.loadtxt("./Large Models/NewModel/64_16_128_3_0.05/train_accuracy.txt")
LNMvalidation_accuracy = np.loadtxt("./Large Models/NewModel/64_16_128_3_0.05/validation_accuracy.txt")

LPTtrain_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05/validation_accuracy.txt")

data = [[LNMtrain_accuracy, LNMvalidation_accuracy], [LPTtrain_accuracy, LPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
LNMtrain_accuracy = np.loadtxt("./Large Models/NewModel/64_16_128_3_0.2/train_accuracy.txt")
LNMvalidation_accuracy = np.loadtxt("./Large Models/NewModel/64_16_128_3_0.2/validation_accuracy.txt")

LPTtrain_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.2/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.2/validation_accuracy.txt")

data = [[LNMtrain_accuracy, LNMvalidation_accuracy], [LPTtrain_accuracy, LPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
LNMtrain_accuracy = np.loadtxt("./Large Models/NewModel/64_32_128_3_0.05/train_accuracy.txt")
LNMvalidation_accuracy = np.loadtxt("./Large Models/NewModel/64_32_128_3_0.05/validation_accuracy.txt")

LPTtrain_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_32_128_3_0.05/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_32_128_3_0.05/validation_accuracy.txt")

data = [[LNMtrain_accuracy, LNMvalidation_accuracy], [LPTtrain_accuracy, LPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
LNMtrain_accuracy = np.loadtxt("./Large Models/NewModel/64_32_128_3_0.2/train_accuracy.txt")
LNMvalidation_accuracy = np.loadtxt("./Large Models/NewModel/64_32_128_3_0.2/validation_accuracy.txt")

LPTtrain_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_32_128_3_0.2/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_32_128_3_0.2/validation_accuracy.txt")

data = [[LNMtrain_accuracy, LNMvalidation_accuracy], [LPTtrain_accuracy, LPTvalidation_accuracy]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train','Pretrained Validation']]
titles = ['Standard Set Transformer','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %% [markdown]
# # ****************** Large END **********************

# %% [markdown]
# # Best model
# ## Pretrained vs Pretrained additional layer variation
# ### Both with same architecture difference
#
# # ****************** Large START *********************

# %%
LPTtrain_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05/validation_accuracy.txt")

LPTtrain_accuracy_1024 = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05_1024/train_accuracy.txt")
LPTvalidation_accuracy_1024 = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05_1024/validation_accuracy.txt")

data = [[LPTtrain_accuracy, LPTvalidation_accuracy], [LPTtrain_accuracy_1024, LPTvalidation_accuracy_1024]]
labels = [['Pretrained Train','Pretrained Validation'],['Pretrained Train 1024','Pretrained Validation 1024']]
titles = ['Contrastive pretrained model','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
LPTtrain_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05/validation_accuracy.txt")

LPTtrain_accuracy_128 = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05_128/train_accuracy.txt")
LPTvalidation_accuracy_128 = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05_128/validation_accuracy.txt")

data = [[LPTtrain_accuracy, LPTvalidation_accuracy], [LPTtrain_accuracy_128, LPTvalidation_accuracy_128]]
labels = [['Pretrained Train','Pretrained Validation'],['Pretrained Train 128','Pretrained Validation 128']]
titles = ['Contrastive pretrained model','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %%
LPTtrain_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05/validation_accuracy.txt")

LPTtrain_accuracy_128 = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05_64_0.05/train_accuracy.txt")
LPTvalidation_accuracy_128 = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05_64_0.05/validation_accuracy.txt")

data = [[LPTtrain_accuracy, LPTvalidation_accuracy], [LPTtrain_accuracy_128, LPTvalidation_accuracy_128]]
labels = [['Pretrained Train','Pretrained Validation'],['Pretrained Train 64','Pretrained Validation 64']]
titles = ['Contrastive pretrained model','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %% [markdown]
# # Large Model results ************* FINAL *********************
# ### batch size = 4, training subsample size = 8000, validation subsample size = 2048
# ### From scratch
# #### embeded dim = 64 induced dim = 128 dropout = 0.05 stack = 3 optimizer: Adam = 1e-3 epochs = 250
# #### Gelu activation
#
# ## Pretrainedmodel
# #### batch size = 32, training subsample size = 1024
# #### embeded dim = 64 induced dim = 128 dropout = 0.05 stack = 3 optimizer: Adam = 1e-3 epochs = 200 temperature = 2.0
#
# #### additional layer with LeakyReLU: projection_dim = 128 dropout = 0.1 optimizer: Adam = 1e-3 epochs = 250

# %%
LPTtrain_accuracy = np.loadtxt("./Large Models/NewModel/64_16_128_3_0.05_final/train_accuracy.txt")
LPTvalidation_accuracy = np.loadtxt("./Large Models/NewModel/64_16_128_3_0.05_final/validation_accuracy.txt")
# PointCloud/BodyScan/SecondWorkingDraft/Large Models/NewModel/64_16_128_3_0.05_final
LPTtrain_accuracy_128 = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05_final/train_accuracy.txt")
LPTvalidation_accuracy_128 = np.loadtxt("./Large Models/Pretrained/masked_encoder_64_16_128_3_0.05_final/validation_accuracy.txt")

data = [[LPTtrain_accuracy, LPTvalidation_accuracy], [LPTtrain_accuracy_128, LPTvalidation_accuracy_128]]
labels = [['NewModel Train','NewModel Validation'],['Pretrained Train 128','Pretrained Validation 128']]
titles = ['Standard Set Transformer','Contrastive pretrained model']

plot_accuracy(data, labels, y_label = 'Accuracy (P)', title = titles)

# %% [markdown]
# # Variation in Additional layers

# %%
# PointCloud/BodyScan/ThirdWorkingDraft/Large Models/Pretrained_AdditionalLayers/JustLinear

train_accuracies = np.loadtxt("./Large Models/Pretrained_AdditionalLayers/JustLinear/train_accuracy.txt")
validation_accuracies = np.loadtxt("./Large Models/Pretrained_AdditionalLayers/JustLinear/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# PointCloud/BodyScan/ThirdWorkingDraft/Large Models/Pretrained_AdditionalLayers/JustLinear

train_accuracies = np.loadtxt("./Large Models/Pretrained_AdditionalLayers/NoDropout/train_accuracy.txt")
validation_accuracies = np.loadtxt("./Large Models/Pretrained_AdditionalLayers/NoDropout/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# PointCloud/BodyScan/ThirdWorkingDraft/Large Models/Pretrained_AdditionalLayers/JustLinear

train_accuracies = np.loadtxt("./Large Models/Pretrained_AdditionalLayers/NoNonLinear/train_accuracy.txt")
validation_accuracies = np.loadtxt("./Large Models/Pretrained_AdditionalLayers/NoNonLinear/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Additional experiments with lowest possible induce points

# %%
train_losses = np.loadtxt("./Large Models/NewModel/64_16_32_3_0.05/train_loss.txt")
train_accuracies = np.loadtxt("./Large Models/NewModel/64_16_32_3_0.05/train_accuracy.txt")
validation_losses = np.loadtxt("./Large Models/NewModel/64_16_32_3_0.05/validation_loss.txt")
validation_accuracies = np.loadtxt("./Large Models/NewModel/64_16_32_3_0.05/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, train_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()


plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
train_losses = np.loadtxt("./Large Models/NewModel/64_16_16_3_0.05/train_loss.txt")
train_accuracies = np.loadtxt("./Large Models/NewModel/64_16_16_3_0.05/train_accuracy.txt")
validation_losses = np.loadtxt("./Large Models/NewModel/64_16_16_3_0.05/validation_loss.txt")
validation_accuracies = np.loadtxt("./Large Models/NewModel/64_16_16_3_0.05/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, train_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()


plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
train_losses = np.loadtxt("./Small Models/NewModel/32_16_16_3_0.05/train_loss.txt")
train_accuracies = np.loadtxt("./Small Models/NewModel/32_16_16_3_0.05/train_accuracy.txt")
validation_losses = np.loadtxt("./Small Models/NewModel/32_16_16_3_0.05/validation_loss.txt")
validation_accuracies = np.loadtxt("./Small Models/NewModel/32_16_16_3_0.05/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, train_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()


plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
train_losses = np.loadtxt("./Small Models/NewModel/32_8_8_3_0.05/train_loss.txt")
train_accuracies = np.loadtxt("./Small Models/NewModel/32_8_8_3_0.05/train_accuracy.txt")
validation_losses = np.loadtxt("./Small Models/NewModel/32_8_8_3_0.05/validation_loss.txt")
validation_accuracies = np.loadtxt("./Small Models/NewModel/32_8_8_3_0.05/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, train_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()


plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
train_losses = np.loadtxt("./Large Models/Pretrained/unmasked_encoder_64_16_16_3_0.2/train_loss.txt")
train_accuracies = np.loadtxt("./Large Models/Pretrained/unmasked_encoder_64_16_16_3_0.2/train_accuracy.txt")
validation_losses = np.loadtxt("./Large Models/Pretrained/unmasked_encoder_64_16_16_3_0.2/validation_loss.txt")
validation_accuracies = np.loadtxt("./Large Models/Pretrained/unmasked_encoder_64_16_16_3_0.2/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, train_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()


plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
train_losses = np.loadtxt("./Large Models/Pretrained/unmasked_encoder_64_16_32_3_0.2/train_loss.txt")
train_accuracies = np.loadtxt("./Large Models/Pretrained/unmasked_encoder_64_16_32_3_0.2/train_accuracy.txt")
validation_losses = np.loadtxt("./Large Models/Pretrained/unmasked_encoder_64_16_32_3_0.2/validation_loss.txt")
validation_accuracies = np.loadtxt("./Large Models/Pretrained/unmasked_encoder_64_16_32_3_0.2/validation_accuracy.txt")

epochs = range(1, 250+1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, train_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()


plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, train_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()
